# %%
def pollutant(p):
    #Parametros de contaminantes
    param = ['CO','NO2', 'O3','PM10','PM25','SO2']
    return (param[p])

# %%
pollutant(1)
# Out:
# 'NO2'

# %%
param[0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-f4019d022ff0> in <module>
# ----> 1 param[0]
#
# TypeError: 'function' object is not subscriptable

# %%
for i in range(6):
    print (i)
# Out:
# 0
# 1
# 2
# 3
# 4
# 5
