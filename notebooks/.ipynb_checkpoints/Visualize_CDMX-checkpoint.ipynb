# %%
import pandas as pd
import folium

# %%
dir_grl = '/home/edgar/Source/Repos/Observatorio-Ciudades/calidad-aire/data/'
city_stations = pd.read_csv(dir_grl+'raw/Grl/stations/city_stations.csv')
cdmx_data = pd.read_csv(dir_grl+'processed/cdmx/2017-2020.csv')

# %%
cdmx_data
# Out:
#        PARAM       FECHA  HORA  ACO  AJM  ATI  BJU  CAM  CCA  CHO  ...  UIZ  \
# 0         CO  2017-01-01     1  NaN  0.5  0.8  1.0  0.8  0.8  1.1  ...  1.4
# 1         CO  2017-01-01     2  NaN  0.5  0.8  1.3  0.9  0.7  1.1  ...  1.2
# 2         CO  2017-01-01     3  NaN  0.5  1.0  1.1  0.9  0.9  0.9  ...  1.6
# 3         CO  2017-01-01     4  1.2  0.5  0.9  1.2  1.1  1.1  0.8  ...  1.4
# 4         CO  2017-01-01     5  1.0  0.4  1.1  1.4  1.7  1.1  1.5  ...  1.3
# ...      ...         ...   ...  ...  ...  ...  ...  ...  ...  ...  ...  ...
# 233467   SO2  2020-04-30    20  NaN  1.0  1.0  1.0  1.0  0.0  NaN  ...  2.0
# 233468   SO2  2020-04-30    21  NaN  1.0  1.0  0.0  1.0  0.0  NaN  ...  2.0
# 233469   SO2  2020-04-30    22  NaN  1.0  1.0  0.0  2.0  0.0  NaN  ...  2.0
# 233470   SO2  2020-04-30    23  NaN  1.0  1.0  0.0  1.0  0.0  NaN  ...  2.0
# 233471   SO2  2020-04-30    24  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...  NaN
#
#         VIF  XAL  COY  CUT  AJU  GAM  FAR  SAC  LAA
# 0       NaN  1.2  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 1       NaN  2.2  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2       NaN  2.3  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 3       NaN  2.7  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 4       NaN  2.8  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# ...     ...  ...  ...  ...  ...  ...  ...  ...  ...
# 233467  1.0  NaN  NaN  2.0  NaN  NaN  NaN  NaN  NaN
# 233468  1.0  NaN  NaN  2.0  NaN  NaN  NaN  NaN  NaN
# 233469  1.0  NaN  NaN  2.0  NaN  NaN  NaN  NaN  NaN
# 233470  1.0  NaN  NaN  1.0  NaN  NaN  NaN  NaN  NaN
# 233471  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
#
# [233472 rows x 40 columns]

# %%
city_stations[city_stations['city']=='Valle de México']
# Out:
#      Unnamed: 0             city             state  estacionesid  \
# 71           71  Valle de México  Ciudad de México           240
# 72           72  Valle de México  Ciudad de México           241
# 73           73  Valle de México  Ciudad de México           242
# 74           74  Valle de México  Ciudad de México           243
# 75           75  Valle de México  Ciudad de México           244
# 76           76  Valle de México  Ciudad de México           245
# 77           77  Valle de México  Ciudad de México           246
# 78           78  Valle de México  Ciudad de México           248
# 79           79  Valle de México  Ciudad de México           249
# 80           80  Valle de México  Ciudad de México           250
# 81           81  Valle de México  Ciudad de México           251
# 82           82  Valle de México  Ciudad de México           252
# 83           83  Valle de México  Ciudad de México           253
# 84           84  Valle de México  Ciudad de México           254
# 85           85  Valle de México  Ciudad de México           256
# 86           86  Valle de México  Ciudad de México           257
# 87           87  Valle de México  Ciudad de México           258
# 88           88  Valle de México  Ciudad de México           259
# 89           89  Valle de México  Ciudad de México           260
# 90           90  Valle de México  Ciudad de México           262
# 91           91  Valle de México  Ciudad de México           263
# 92           92  Valle de México  Ciudad de México           265
# 93           93  Valle de México  Ciudad de México           266
# 94           94  Valle de México  Ciudad de México           267
# 95           95  Valle de México  Ciudad de México           268
# 96           96  Valle de México  Ciudad de México           269
# 97           97  Valle de México  Ciudad de México           270
# 98           98  Valle de México  Ciudad de México           271
# 102         102  Valle de México  Ciudad de México           299
# 103         103  Valle de México  Ciudad de México           300
# 104         104  Valle de México  Ciudad de México           301
# 105         105  Valle de México  Ciudad de México           302
#
#                           _id        lat       long  \
# 71   5cccf5bee2705c19328205ed  19.635556 -98.912222
# 72   5cccf5bee2705c19328205ee  19.154286 -99.162778
cdmx_filter.to_csv(dir_grl+'processed/cdmx/cdmx_2017-2020_filtered.csv')
cdmx_filter
# Out:
#                        ACO  AJU  AJM  ATI  CAM  CCA  CHO  CUA  CUT  FAC  ...  \
# FECHA      HORA PARAM                                                    ...
# 2017-01-01 1    CO     NaN  NaN  0.5  0.8  0.8  0.8  1.1  0.5  NaN  1.7  ...
#            2    CO     NaN  NaN  0.5  0.8  0.9  0.7  1.1  0.6  NaN  1.2  ...
#            3    CO     NaN  NaN  0.5  1.0  0.9  0.9  0.9  0.7  NaN  1.3  ...
#            4    CO     1.2  NaN  0.5  0.9  1.1  1.1  0.8  0.6  NaN  1.1  ...
#            5    CO     1.0  NaN  0.4  1.1  1.7  1.1  1.5  0.5  NaN  1.1  ...
# ...                    ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...
# 2020-04-30 20   SO2    NaN  NaN  1.0  1.0  1.0  0.0  NaN  1.0  2.0  2.0  ...
#            21   SO2    NaN  NaN  1.0  1.0  1.0  0.0  NaN  1.0  2.0  1.0  ...
#            22   SO2    NaN  NaN  1.0  1.0  2.0  0.0  NaN  1.0  2.0  1.0  ...
#            23   SO2    NaN  NaN  1.0  1.0  1.0  0.0  NaN  0.0  1.0  1.0  ...
#            24   SO2    NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...
#
#                        TLA  TLI  UIZ  UAX  VIF  XAL  MPA  BJU  INN  GAM
# FECHA      HORA PARAM
# 2017-01-01 1    CO     1.6  NaN  1.4  1.2  NaN  1.2  NaN  1.0  0.1  NaN
#            2    CO     1.4  NaN  1.2  1.4  NaN  2.2  NaN  1.3  0.1  NaN
#            3    CO     1.1  NaN  1.6  1.3  NaN  2.3  NaN  1.1  0.1  NaN
#            4    CO     1.1  NaN  1.4  1.3  NaN  2.7  0.3  1.2  0.1  NaN
#            5    CO     1.0  NaN  1.3  1.4  NaN  2.8  0.2  1.4  0.1  NaN
# ...                    ...  ...  ...  ...  ...  ...  ...  ...  ...  ...
# 2020-04-30 20   SO2    3.0  NaN  2.0  0.0  1.0  NaN  NaN  1.0  0.0  NaN
#            21   SO2    2.0  NaN  2.0  0.0  1.0  NaN  NaN  0.0  0.0  NaN
#            22   SO2    2.0  NaN  2.0  0.0  1.0  NaN  NaN  0.0  0.0  NaN
#            23   SO2    2.0  NaN  2.0  0.0  1.0  NaN  NaN  0.0  0.0  NaN
#            24   SO2    NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
#
# [233472 rows x 32 columns]

# %%
# for i, column in cdmx_filter.iteritems():
    #print (column)
    
centro_lat, centro_lon = 19.442810, -99.131233 #Centro del mapa

#Creacion del mapa
folium_map = folium.Map(location=[centro_lat,centro_lon], zoom_start=10,
                        tiles = 'cartodb positron')

for i, est in city_stations[city_stations['city']=='Valle de México'].iterrows():
    
    est_code = city_stations.loc[(i),'codigo']
    #print (cdmx_filter.loc['2017-01-01', 1, 'CO'])
    
    #Coloca los marcadores en el mapa
    c_value = cdmx_filter.loc[('2019-03-01',1,'PM10'),est_code]

    #Puntos con nombre, latitud y longitud
    popup_text = f"<b> Nombre: </b> {est.nombre} <br> <b> Latitud: </b> {est.lat:.5f} <br> <b> Longitud: </b> {est.long:.5f} <br> <b> Contaminante: </b> {'PM10'} <br> <b> Conc: </b> {c_value} <br>"
    #popup_text = f"<b> Nombre: </b> {est.nombre} <br> <b> Latitud: </b> {est.lat:.5f} <br> <b> Longitud: </b> {est.long:.5f} <br>"
    
    #Coloca los marcadores en el mapa
    folium.CircleMarker(location=[est.lat, est.long], radius=c_value/10,
                        tooltip = popup_text, fill=True, fill_opacity=0.4).add_to(folium_map)
        
folium_map
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-abf057dfe259> in <module>
#      14
#      15     #Coloca los marcadores en el mapa
# ---> 16     c_value = cdmx_filter.loc[('2019-03-01',1,'PM10'),est_code]
#      17
#      18     #Puntos con nombre, latitud y longitud
#
# NameError: name 'cdmx_filter' is not defined

# %%
def colors(conc_nrm):
    
    if conc_nrm<=0.25:
        color = '#3CB371'
    elif conc_nrm<=0.5:
        color = '#FFD700'
    elif conc_nrm<=0.75:
        color = '#FF7F50'
    else:
        color = '#483D8B'
        
    return color

def visualize_aqdata_date(city, pollutant, date):
    
    city_dict = {'cdmx':'Valle de México'}
    
    p_limits = {'PM10':214, 'O3':154, 'CO':16.5,
               'PM25':97.4, 'SO2':195,'NO2':315}
    
    data_bydateParam = pd.read_csv(dir_grl+'processed/'+city+'/'+city+'_2017-2020_filtered_'+pollutant+'.csv').set_index('FECHA')
    
    centro_lat, centro_lon = 19.442810, -99.131233 #Centro del mapa

    #Creacion del mapa
    folium_map = folium.Map(location=[centro_lat,centro_lon], zoom_start=10,
                            tiles = 'cartodb positron')

    for i, est in city_stations[city_stations['city']==city_dict[city]].iterrows():

        est_code = city_stations.loc[(i),'codigo']

        #Coloca los marcadores en el mapa
        c_value = data_bydateParam.loc[(date),est_code]
        c_graph = (data_bydateParam.loc[(date),est_code])/p_limits[pollutant]

        #Puntos con nombre, latitud y longitud
        popup_text = f"<b> Nombre: </b> {est.nombre} <br> <b> Latitud: </b> {est.lat:.5f} <br> <b> Longitud: </b> {est.long:.5f} <br> <b> Contaminante: </b> {pollutant} <br> <b> Conc: </b> {c_value} <br>"

        #Coloca los marcadores en el mapa
        folium.CircleMarker(location=[est.lat, est.long], radius=c_graph*50,
                            tooltip = popup_text, fill=True, color=colors(c_graph),
                            fill_opacity=0.65).add_to(folium_map)

    return(folium_map)

# %%
visualize_aqdata_date('cdmx', 'PM10', '2017-03-31')
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
def clr_change(conc_cmp):
    
    if conc_cmp>=0:
        color = '#F84A50'
    else:
        color = '#6086CA'
        
    return color

def compare_year_prior(city, pollutant, date):
    
    city_dict = {'cdmx':'Valle de México'}
    
    prev_year = str(int(date[:4])-1)+date[4:]
    
    data_bydateParam = pd.read_csv(dir_grl+'processed/'+city+'/'+city+'_2017-2020_filtered_'+pollutant+'.csv').set_index('FECHA')
    
    centro_lat, centro_lon = 19.442810, -99.131233 #Centro del mapa

    #Creacion del mapa
    folium_map = folium.Map(location=[centro_lat,centro_lon], zoom_start=10,
                            tiles = 'cartodb positron')

    for i, est in city_stations[city_stations['city']==city_dict[city]].iterrows():

        est_code = city_stations.loc[(i),'codigo']

        #Coloca los marcadores en el mapa
        c_current = data_bydateParam.loc[(date),est_code]
        c_prev = data_bydateParam.loc[(prev_year),est_code]
        c_graph = (c_current - c_prev)/c_prev

        #Puntos con nombre, latitud y longitud
        popup_text = f"<b> Nombre: </b> {est.nombre} <br> <b> Latitud: </b> {est.lat:.5f} <br> <b> Longitud: </b> {est.long:.5f} <br> <b> Contaminante: </b> {pollutant} <br> <b> Conc: </b> {c_graph} <br>"

        #Coloca los marcadores en el mapa
        folium.CircleMarker(location=[est.lat, est.long], radius=abs(c_graph)*50,
                            tooltip = popup_text, fill=True, color=clr_change(c_graph),
                            fill_opacity=0.65).add_to(folium_map)

    return(folium_map)

# %%
compare_year_prior('cdmx', 'PM10', '2018-01-10')
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
