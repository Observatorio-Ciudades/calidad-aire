# %%
import pandas as pd
import os
import numpy as np

# %%
dir_mty = '../data/raw/mty_aqip/'

# %%
for file in os.listdir(dir_mty):
    print (file[0:file.find(',')])
# Out:
# san-nicolás
# obispado
# garcía
# cadereyta
# s.-pedro
# universidad
# escobedo
# juárez
# pueblo-serena
# apodaca
# metrorrey
# pastora
# s.-catarina

# %%
def pollutant(p):
    """Function that returns a str with a pollutant.

    Args:
        p (int): values from 0 to 5 for list place.

    Returns:
        str: pollutant.
    """
    #Parametros de contaminantes
    param = ['CO','NO2', 'O3','PM10','PM25','SO2']
    return (param[p])


def mty_data ():
    dir_mty = '../data/raw/mty_aqip/'
    
    est_dict = {'san-nicolás':'NE', 'obispado':'CE', 'garcía':'NO2', 'cadereyta':'SE3',
               's.-pedro':'SO2', 'universidad':'N2', 'escobedo':'N', 'juárez':'SE2',
               'pueblo-serena':'SUR', 'apodaca':'NE2', 'metrorrey':'NO' ,'pastora':'SE',
               's.-catarina':'SO'}
    
    for i in range (6):
    
        #df = pd.DataFrame()
        
        df = pd.DataFrame(columns=['O3','CO','PM10','SO2','NO2','PM25'])

        for year in range(2017,2020):

            df2 = pd.DataFrame()

            y = str(year)

            if year ==2020:

                df2['FECHA'] = pd.date_range(start = pd.Timestamp(y), 
                                           end = pd.Timestamp('2020-05-31')  ,
                                           freq = 'D')

            else:

                df2['FECHA'] = pd.date_range(start = pd.Timestamp(y), 
                                           end = pd.Timestamp(y) + pd.tseries.offsets.YearEnd(0)    ,
                                           freq = 'D')

            df = df.append(df2)


            df['FECHA'] = pd.to_datetime(df['FECHA'])
            df = df.set_index('FECHA')
            df = df.stack(dropna=False)
            all_data = pd.DataFrame(df)
            all_data = all_data.rename_axis(index=['FECHA','PARAM'])
            all_data = all_data.drop(columns=[0])
            
            #print(all_data)

        for file in os.listdir(dir_mty):


            #print(all_data)

            mty_data = pd.read_csv(dir_mty+file).rename(columns={'date':'FECHA', 'pm25':'PM25','pm10':'PM10',
                                                                'o3':'O3','no2':'NO2','so2':'SO2','co':'CO'}).replace(r'^\s*$', np.nan, regex=True)

            est = file[0:file.find(',')]
            
            print(file[0:file.find(',')])

            #gdl_data.columns = [col.strip() for col in gdl_data.columns]

            #gdl_data = gdl_data[['FECHA','O3','NO2','SO2','PM10','CO']]

            #mty_data['FECHA'] = mty_data['FECHA'].dt.date

            mty_stack = pd.DataFrame(mty_data.set_index(['FECHA']).stack([0]))

            mty_stack = mty_stack.reset_index().rename(columns={'level_1':'PARAM',
                                                                0:est_dict[est]})

            #mty_stack['FECHA'] = pd.to_datetime(mty_stack['FECHA'])

            mty_stack = mty_stack.set_index(['FECHA','PARAM'])

            #gdl_stack['FECHA'] = pd.to_datetime(gdl_stack['FECHA'])

            #gdl_stack = gdl_stack[gdl_stack['FECHA'].dt.year==int(file[6:10])]

            #gdl_stack[est_dict[s.strip(' ').upper()]] = pd.to_numeric(gdl_stack[est_dict[s.strip(' ').upper()]], errors='coerce')

            #gdl_stack = gdl_stack.groupby(['FECHA','PARAM']).mean()

            all_data = pd.merge(all_data, mty_stack, how='left',left_index=True, right_index=True)


            print (all_data)
            #all_data.to_csv(dir_gdl+'stack/'+file[6:10]+'.csv')

# %%
mty_data()
# Out:
# san-nicolás
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/anaconda3/envs/geo_env/lib/python3.8/site-packages/pandas/core/algorithms.py in safe_sort(values, codes, na_sentinel, assume_unique, verify)
#    2014         try:
# -> 2015             sorter = values.argsort()
#    2016             ordered = values.take(sorter)
#
# TypeError: '<' not supported between instances of 'Timestamp' and 'str'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-46-3faef4d3fe1e> in <module>
# ----> 1 mty_data()
#
# <ipython-input-45-c9a104feffb6> in mty_data()
#      92             #gdl_stack = gdl_stack.groupby(['FECHA','PARAM']).mean()
#      93
# ---> 94             all_data = pd.merge(all_data, mty_stack, how='left',left_index=True, right_index=True)
#      95
#      96
#
# ~/anaconda3/envs/geo_env/lib/python3.8/site-packages/pandas/core/reshape/merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      86         validate=validate,
#      87     )
# ---> 88     return op.get_result()
#      89
#      90
#
# ~/anaconda3/envs/geo_env/lib/python3.8/site-packages/pandas/core/reshape/merge.py in get_result(self)
#     641             self.left, self.right = self._indicator_pre_merge(self.left, self.right)
#     642
# --> 643         join_index, left_indexer, right_indexer = self._get_join_info()
#     644
#     645         ldata, rdata = self.left._data, self.right._data
#
# ~/anaconda3/envs/geo_env/lib/python3.8/site-packages/pandas/core/reshape/merge.py in _get_join_info(self)
#     847
#     848         if self.left_index and self.right_index and self.how != "asof":
# --> 849             join_index, left_indexer, right_indexer = left_ax.join(
#     850                 right_ax, how=self.how, return_indexers=True, sort=self.sort
#     851             )
#
# ~/anaconda3/envs/geo_env/lib/python3.8/site-packages/pandas/core/indexes/base.py in join(self, other, how, level, return_indexers, sort)
#    3308                 )
#    3309             else:
# -> 3310                 return self._join_non_unique(
#    3311                     other, how=how, return_indexers=return_indexers
#    3312                 )
#
# ~/anaconda3/envs/geo_env/lib/python3.8/site-packages/pandas/core/indexes/base.py in _join_non_unique(self, other, how, return_indexers)
#    3426         from pandas.core.reshape.merge import _get_join_indexers
#    3427
# -> 3428         left_idx, right_idx = _get_join_indexers(
#    3429             [self._ndarray_values], [other._ndarray_values], how=how, sort=True
#    3430         )
#
# ~/anaconda3/envs/geo_env/lib/python3.8/site-packages/pandas/core/reshape/merge.py in _get_join_indexers(left_keys, right_keys, sort, how, **kwargs)
#    1309         for n in range(len(left_keys))
#    1310     )
# -> 1311     zipped = zip(*mapped)
#    1312     llab, rlab, shape = [list(x) for x in zipped]
#    1313
#
# ~/anaconda3/envs/geo_env/lib/python3.8/site-packages/pandas/core/reshape/merge.py in <genexpr>(.0)
#    1306     # get left & right join labels and num. of levels at each location
#    1307     mapped = (
# -> 1308         _factorize_keys(left_keys[n], right_keys[n], sort=sort)
#    1309         for n in range(len(left_keys))
#    1310     )
#
# ~/anaconda3/envs/geo_env/lib/python3.8/site-packages/pandas/core/reshape/merge.py in _factorize_keys(lk, rk, sort)
#    1922     if sort:
#    1923         uniques = rizer.uniques.to_array()
# -> 1924         llab, rlab = _sort_labels(uniques, llab, rlab)
#    1925
#    1926     # NA group
#
# ~/anaconda3/envs/geo_env/lib/python3.8/site-packages/pandas/core/reshape/merge.py in _sort_labels(uniques, left, right)
#    1948     labels = np.concatenate([left, right])
#    1949
# -> 1950     _, new_labels = algos.safe_sort(uniques, labels, na_sentinel=-1)
#    1951     new_labels = ensure_int64(new_labels)
#    1952     new_left, new_right = new_labels[:llength], new_labels[llength:]
#
# ~/anaconda3/envs/geo_env/lib/python3.8/site-packages/pandas/core/algorithms.py in safe_sort(values, codes, na_sentinel, assume_unique, verify)
#    2017         except TypeError:
#    2018             # try this anyway
# -> 2019             ordered = sort_mixed(values)
#    2020
#    2021     # codes:
#
# ~/anaconda3/envs/geo_env/lib/python3.8/site-packages/pandas/core/algorithms.py in sort_mixed(values)
#    2000         # order ints before strings, safe in py3
#    2001         str_pos = np.array([isinstance(x, str) for x in values], dtype=bool)
# -> 2002         nums = np.sort(values[~str_pos])
#    2003         strs = np.sort(values[str_pos])
#    2004         return np.concatenate([nums, np.asarray(strs, dtype=object)])
#
# <__array_function__ internals> in sort(*args, **kwargs)
#
# ~/anaconda3/envs/geo_env/lib/python3.8/site-packages/numpy/core/fromnumeric.py in sort(a, axis, kind, order)
#     987     else:
#     988         a = asanyarray(a).copy(order="K")
# --> 989     a.sort(axis=axis, kind=kind, order=order)
#     990     return a
#     991
#
# TypeError: '<' not supported between instances of 'Timestamp' and 'str'

# %%
df = pd.DataFrame()
    
for year in range(2017,2021):

    df2 = pd.DataFrame()
    
    y = str(year)

    if year ==2020:

        df2['Date'] = pd.date_range(start = pd.Timestamp(y), 
                                   end = pd.Timestamp('2020-05-31')  ,
                                   freq = 'D')

    else:

        df2['Date'] = pd.date_range(start = pd.Timestamp(y), 
                                   end = pd.Timestamp(y) + pd.tseries.offsets.YearEnd(0)    ,
                                   freq = 'D')

    df = df.append(df2)
    
df
# Out:
#           Date
# 0   2017-01-01
# 1   2017-01-02
# 2   2017-01-03
# 3   2017-01-04
# 4   2017-01-05
# ..         ...
# 147 2020-05-27
# 148 2020-05-28
# 149 2020-05-29
# 150 2020-05-30
# 151 2020-05-31
#
# [1247 rows x 1 columns]
